# %%
# Dependencies
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import seaborn as sns

# %%
def linregres_func(x_values, y_values, x_label, y_label, ann_horizontal, ann_vertical): # savefile
                                                                            
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    regress_values = x_values * slope + intercept
    eq_line = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values, y_values, c='lightskyblue', edgecolor='maroon')
    plt.plot(x_values, regress_values, 'r-')
    plt.annotate(eq_line, (ann_horizontal, ann_vertical), fontsize=11, color='red')
    plt.title(f" {x_label} vs {y_label} \n Y2017")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.tight_layout
    print(f"The r-squared is: {rvalue}")
#     plt.savefig(f'figures/{savefile}')
    plt.show()

# %% [markdown]
# ## Other Variables Data Correlation

# %%
# Load/Read Happiness Index or Ladder Score
pd.set_option('display.max_columns', None)
path_df_2017 = "Data sets/df_2017.csv"
df_2017 = pd.read_csv(path_df_2017)
df_2017.drope
df_2017.head()
# Out:
#    Unnamed: 0 Country name Code  year      GDP  Happiness Index  Log GDP  \
# 0           0  Afghanistan  AFG  2017   2203.0             2.66     7.47
# 1           1      Albania  ALB  2017  13094.0             4.64     9.38
# 2           2    Argentina  ARG  2017  23563.0             6.04     9.85
# 3           3      Armenia  ARM  2017  12115.0             4.29     9.08
# 4           4    Australia  AUS  2017  48905.0             7.26    10.71
#
#    Social support  Healthy life exp  Freedom  Generosity  Pct corruption  \
# 0            0.49              52.8     0.43       -0.11            0.95
# 1            0.64              68.4     0.75       -0.03            0.88
# 2            0.91              68.6     0.83       -0.18            0.84
# 3            0.70              66.6     0.61       -0.13            0.86
# 4            0.95              73.3     0.91        0.31            0.41
#
#    Blue Index  Suicide  Depression & Anxiety  Substance Abuse  \
# ...

# %% [markdown]
# ### Correlations

# %%
# Economic Health vs Happiness Index
Economic_health_pCorrelation = other_2017.loc[:, ['Happiness Index', 'Log GDP per capita', 'Unemployment rate']]

# %%
Economic_health_pCorrelation = Economic_health_pCorrelation.corr(method='pearson')
Economic_health_pCorrelation
# Out:
#                     Happiness Index  Log GDP per capita  Unemployment rate
# Happiness Index            1.000000            0.771261          -0.192692
# Log GDP per capita         0.771261            1.000000           0.085940
# Unemployment rate         -0.192692            0.085940           1.000000

# %% [markdown]
# Remove happiness index, GDP,
# + literecy, braindrain, securitythreat
# + happiness variables
# + reorder from most highest to lowest

# %%
# %matplotlib notebook

# %%
# Plot and display heat map of Economic_health_pCorrelation
# %matplotlib notebook
sns.heatmap(Economic_health_pCorrelation, 
            xticklabels=Economic_health_pCorrelation.columns,
            yticklabels=Economic_health_pCorrelation.columns,
            cmap='bwr',
            annot=True,
            linewidth=0.5)
plt.title('Economic Health and Happiness Index \n Correlation Heat Map \n ', fontsize= 10)
plt.tight_layout()
plt.savefig('figures/EconomicVsHappinessHeatmap')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %%
# Economic Health vs Happiness Index
otherFactors_correlation = other_2017.loc[:, ['Happiness Index', 'Brain drain index', 'Unemployment rate', 'Security threats index',
                                  'Fragile state index', 'Poverty percent of population', 'Unemployment rate',
                                  'Physician perpop', 'Substance Abuse', 'Depression & Anxiety', 'Public spending on education',
                                  'Suicide', 'Blue Index', 'Tourist arrivals', 'Int tourism revenue', 'Average Age', 
                                  'Literacy rate', 'Sleep (min)' ]]

# %%
otherFactors_correlation = otherFactors_correlation.corr(method='pearson').round(decimals=2)
otherFactors_correlation
# Out:
#                                Happiness Index  Brain drain index  \
# Happiness Index                           1.00              -0.74
# Brain drain index                        -0.74               1.00
# Unemployment rate                        -0.19              -0.03
# Security threats index                   -0.54               0.66
# Fragile state index                      -0.37               0.42
# Poverty percent of population            -0.38               0.64
# Unemployment rate                        -0.19              -0.03
# Physician perpop                          0.06              -0.16
# Substance Abuse                           0.21              -0.37
# Depression & Anxiety                      0.25              -0.48
# Public spending on education              0.19               0.25
# Suicide                                   0.21              -0.37
# Blue Index                                0.14              -0.16
# ...

# %%
# %matplotlib notebook
sns.set(font_scale=.65)
sns.heatmap(otherFactors_correlation, 
            xticklabels=otherFactors_correlation.columns,
            yticklabels=otherFactors_correlation.columns,
            cmap="RdPu",
            annot=True,
            linewidth=0.5)
plt.title('Happiness and other Factors \n Correlation Heat Map \n ', fontsize= 10)
plt.tight_layout()
plt.savefig('figures/EconomicVsHappinessHeatmap')
plt.show()
# Out:
# ---------------------------------------------------------------
# NameError                     Traceback (most recent call last)
# <ipython-input-8-4206094c6306> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
#       2 sns.set(font_scale=.65)
# ----> 3 sns.heatmap(otherFactors_correlation,
#       4             xticklabels=otherFactors_correlation.columns,
#       5             yticklabels=otherFactors_correlation.columns,
#
# NameError: name 'otherFactors_correlation' is not defined

# %%
GDP_2017 = other_2017.loc[:, ['Country', 'Happiness Index', 'Log GDP per capita', 'Freedom' ]]
GDP_2017.head(10)
# Out:
#        Country  Happiness Index  Log GDP per capita   Freedom
# 0  Afghanistan         2.661718            7.472197  0.427011
# 1      Albania         4.639548            9.376133  0.749611
# 2      Algeria         5.248912            9.537937  0.436670
# 3    Argentina         6.039330            9.849303  0.831966
# 4      Armenia         4.287736            9.076206  0.613697
# 5    Australia         7.257038           10.711926  0.910550
# 6      Austria         7.293728           10.725315  0.890031
# 7   Azerbaijan         5.152279            9.675921  0.731030
# 8      Bahrain         6.227321           10.676380  0.905859
# 9   Bangladesh         4.309771            8.198176  0.896217

# %%
sns.relplot(x='Happiness Index', y='Happiness Index', hue='Freedom', data=GDP_2017);

# %%
GDP_2017.describe()
# Out:
#        Happiness Index  Log GDP per capita
# count       140.000000          140.000000
# mean          5.495144            9.312034
# std           1.124027            1.193967
# min           2.661718            6.625160
# 25%           4.621274            8.380398
# 50%           5.586507            9.485155
# 75%           6.278276           10.298285
# max           7.788252           11.441448

# %%
# Determine Top GDP
top_GDP_countries = GDP_2017.sort_values(['Log GDP per capita'], ascending=False) 
top_GDP_countries.tail(1)
# Out:
#                      Country Code  Year  Happiness Index  Log GDP per capita
# 23  Central African Republic  CAF  2017         3.475862             6.62516

# %%
GDP_2017['Happiness Index'].max()
# Out:
# 7.788251877

# %%
# cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
# ax = sns.scatterplot(x='Log GDP per capita', y='Happiness Index',
#                     hue='size', size='size',
#                     sizes=(20, 200), hue_norm=(0, 7))

# %% [markdown]
# ### GINI Income Inequality Index

# %%
GINI_2017 = other_2017.loc[:, ['Country', 'Code', 'Year', 'Happiness Index', 'GINI of household' ]]
GINI_2017.head(1)
# Out:
#        Country Code  Year  Happiness Index  GINI of household
# 0  Afghanistan  AFG  2017         2.661718                NaN

# %%
# Quick check about total NaNs and non-Null values
GINI_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            140 non-null    object
#  1   Code               140 non-null    object
#  2   Year               140 non-null    int64
#  3   Happiness Index    140 non-null    float64
#  4   GINI of household  130 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 5.6+ KB

# %% [markdown]
# Gini index < 0.2 represents perfect income equality, 0.2–0.3 relative equality, 0.3–0.4 adequate equality, 0.4–0.5 big income gap, and above 0.5 represents severe income gap.

# %%
# Determine Top countries with data on GINI index - worst income gap
top_GINI_countries = GINI_2017.sort_values(['GINI of household'], ascending=False) 
top_GINI_countries.head(1)
# Out:
#           Country Code  Year  Happiness Index  GINI of household
# 116  South Africa  ZAF  2017         4.513655              0.624

# %% [markdown]
# Interesting country: Brazil, Honduras, Colombia, Panama
#
# Very happy BUT has one of the severe household income gap or GINI index

# %%
# Countries with less GINI or with relatively equal income of Household
less_GINI_countries = GINI_2017.sort_values(['GINI of household'], ascending=True) 
less_GINI_countries.head(1)
# Out:
#       Country Code  Year  Happiness Index  GINI of household
# 115  Slovenia  SVN  2017         6.166838             0.2495

# %% [markdown]
# Interesting country:
# Ukraine
# - Not very happy but has a relatively equal householdincome

# %% [markdown]
# ### GINI Index vs Happiness

# %%
plt.scatter(other_2017['GINI of household'],other_2017['Happiness Index'],marker='o', c='cyan',
            edgecolor= 'black', alpha=0.70, s=50)
plt.title(f"Figure : GINI of household vs. Happiness \n Y2017")
plt.xlabel(f"GINI of household")
plt.ylabel(f"Happiness Index")
plt.grid(True)
plt.tight_layout
# plt.savefig('../Fig_GINI_of_householdvsHappiness.png')
plt.show()

# %%
linregres_func(other_2017['GINI of household'], other_2017['Happiness Index'], 'GINI of household', 'Happiness Index', 0.45, 7.5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# The r-squared is: nan

# %% [markdown]
# ### Poverty (% of Pop)

# %%
poverty_2017 = other_2017.loc[:, ['Country', 'Code', 'Year', 'Happiness Index', 'Poverty (% of Pop)' ]]
poverty_2017.head(1)
# Out:
# ---------------------------------------------------------------
# KeyError                      Traceback (most recent call last)
# <ipython-input-15-fcc50de45674> in <module>
# ----> 1 poverty_2017 = other_2017.loc[:, ['Country', 'Code', 'Year', 'Happiness Index', 'Poverty (% of Pop)' ]]
#       2 poverty_2017.head(1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1759                 except (KeyError, IndexError, AttributeError):
#    1760                     pass
# -> 1761             return self._getitem_tuple(key)
#    1762         else:
#    1763             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1286                 continue
#    1287
# -> 1288             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1289
#    1290         return retval
#
# ...

# %%
poverty_2017.info()

# %%
# Determine Top countries in Poverty
top_poverty = poverty_2017.sort_values(['Poverty (% of Pop)'], ascending=False) 
top_poverty.head(10)

# %% [markdown]
# Interesting country:
# Honduras
# - High Poverty (% of Pop) but happier

# %%
# Determine countries with less Poverty
less_poverty = poverty_2017.sort_values(['Poverty (% of Pop)'], ascending=True) 
less_poverty.head(10)

# %% [markdown]
# ### Unemployment vs Happiness

# %%
unemployment_2017 = other_2017.loc[:, ['Country', 'Code', 'Year', 'Happiness Index', 'Unemployment rate' ]]
unemployment_2017.head(1)

# %%
unemployment_2017.info()

# %%
# Determine Top countries with Unemployment rate
top_Unemployment = unemployment_2017.sort_values(['Unemployment rate'], ascending=False) 
top_Unemployment.head(30)

# %% [markdown]
# Interesting country: Spain - belongs to top 10 for unemployment rate, yet is one of the countries that has a high Happiness score?

# %%
# Determine countries with Least Problems on Unemployment
less_Unemployment = unemployment_2017.sort_values(['Unemployment rate'], ascending=True) 
less_Unemployment.head(30)

# %% [markdown]
# Interesting countries:
# Nepal, Niger, &  Cambodia
# - No problems with unemployment but not as happier than others

# %%
plt.scatter(other_2017['Unemployment rate'],other_2017['Happiness Index'],marker='o', c='cyan',
            edgecolor= 'black', alpha=0.70, s=50)
plt.title(f"Figure : Unemployment vs. Happiness \n Y2017")
plt.xlabel(f"Unemployment rate")
plt.ylabel(f"Happiness Index")
plt.grid(True)
plt.tight_layout
# plt.savefig('../Fig_Gini income inequality indexvsHappiness.png')
plt.show()

# %%
linregres_func(other_2017['Unemployment rate'], other_2017['Happiness Index'], 'Unemployment', 'Happiness Index', 11, 7)
