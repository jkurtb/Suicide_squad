# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# FUNCTION DEFINITION: function to create DataFrameMatrix with define row_name and col_name 
def matrix_maker_function(dataframe,row_name,col_name):
    df = dataframe.filter([row_name,col_name,'val'], axis=1)
    matrix_df = pd.pivot_table(df,index=[row_name],values=["val"],columns=[col_name])             
    matrix_df = pd.DataFrame(matrix_df.to_records())                                  
    matrix_df.columns = [hdr.replace("('val', ", "").replace(")", "") \
                     for hdr in matrix_df.columns]
    return matrix_df

# %%
# SUICIDE RATE MATRIX
# Read file
file = pd.read_csv("ghdx_healthdata c_3_1 selfharm.csv")
file.replace(['Taiwan (Province of China)'], ['Taiwan'],inplace=True)

# Create base dataframe for Suicide Rate for all countries ; CauseNo = 718 for selfharm/suicide, MetricId = 3 Rate 
suicide_df = file[(file["sex_id"]==3) & (file["metric_id"]==3) & (file["measure_id"]==1) & (file["cause_id"] == 718)].round(2)

#create matrix
suicide_rate_df = matrix_maker_function(suicide_df ,'location_name','year')
suicide_rate_df.rename(columns={"location_name":"Country Name"}, inplace=True)
suicide_rate_df.head(10)
# Out:
#           Country Name   1990   1991   1992   1993   1994   1995   1996  \
# 0          Afghanistan   7.40   7.33   6.98   6.82   6.84   6.77   6.65
# 1              Albania   3.63   3.85   3.77   3.69   3.57   3.74   4.02
# 2              Algeria   3.99   4.04   4.11   4.20   4.40   4.49   4.59
# 3       American Samoa   5.91   5.86   5.80   5.79   5.78   5.76   5.74
# 4              Andorra  13.04  13.15  13.20  13.11  12.89  12.62  12.42
# 5               Angola   8.71   8.74   8.82   9.03   9.16   8.98   8.42
# 6  Antigua and Barbuda   2.49   2.50   2.50   2.51   2.51   2.51   2.54
# 7            Argentina   9.68  10.00  10.68  10.91  11.28  11.54  12.05
# 8              Armenia   3.14   3.30   3.67   3.96   4.11   4.22   4.11
# 9            Australia  13.95  13.83  13.84  13.47  13.94  14.06  14.35
#
#     1997   1998  ...   2008   2009   2010   2011   2012   2013   2014   2015  \
# 0   6.58   6.53  ...   5.73   5.63   5.54   5.46   5.39   5.35   5.30   5.29
# 1   4.33   4.58  ...   5.76   5.68   5.72   5.75   5.76   5.81   5.88   5.89
# 2   4.70   4.76  ...   4.74   4.67   4.59   4.56   4.49   4.46   4.44   4.39
# 3   5.77   5.74  ...   5.57   5.59   5.69   5.77   5.85   5.93   6.01   6.17
# 4  12.48  12.33  ...  11.18  11.10  10.99  10.70  10.63  10.55  10.32  10.21
# 5   8.20   8.87  ...   7.00   6.87   6.74   6.66   6.60   6.50   6.30   6.24
# 6   2.59   2.66  ...   2.75   2.79   2.82   2.87   2.86   2.88   2.92   2.95
# 7  12.36  12.47  ...  11.62  11.57  11.34  11.49  11.69  11.72  11.48  11.26
# 8   3.96   3.81  ...   8.73   9.25   9.75  10.12  10.34  10.12  10.08  10.16
# 9  14.63  14.73  ...  12.17  12.25  12.30  12.19  12.04  12.12  12.65  13.00
#
#     2016   2017
# 0   5.27   5.25
# 1   5.88   5.86
# 2   4.27   4.20
# 3   6.21   6.26
# 4  10.21  10.24
# 5   6.15   6.19
# 6   2.95   2.95
# 7  11.34  11.35
# 8  10.15   9.97
# 9  12.78  12.76
#
# [10 rows x 29 columns]

# %%
#suicide_rate_df.sort_values(by='1990', ascending=False)
print(suicide_rate_df.sort_values(by='1990', ascending=False)['Country Name'].head())
# Out:
# 67              Greenland
# 76                Hungary
# 161             Sri Lanka
# 154              Slovenia
# 141    Russian Federation
# Name: Country Name, dtype: object

# %%
# SUICIDE BY FIREARM RATE MATRIX
# Create base dataframe for Suicide by firearm Rate for all countries ; CauseNo = 721, MetricId = 3 Rate
firearms_df = file[(file["sex_id"]==3) & (file["metric_id"]==3) & (file["measure_id"]==1) & (file["cause_id"] == 721)].round(2)

#create matrix
byfirearm_rate_df = matrix_maker_function(firearms_df ,'location_name','year')
byfirearm_rate_df.rename(columns={"location_name":"Country Name"}, inplace=True)
byfirearm_rate_df
# Out:
#              Country Name  1990  1991  1992  1993  1994  1995  1996  1997  \
# 0             Afghanistan  0.48  0.47  0.45  0.43  0.43  0.42  0.41  0.40
# 1                 Albania  0.85  0.92  0.91  0.91  0.90  0.98  1.11  1.32
# 2                 Algeria  0.20  0.20  0.21  0.21  0.22  0.23  0.23  0.24
# 3          American Samoa  0.86  0.85  0.84  0.83  0.83  0.83  0.83  0.85
# 4                 Andorra  1.25  1.24  1.24  1.21  1.18  1.15  1.12  1.07
# ..                    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 190               Vietnam  0.21  0.21  0.21  0.21  0.21  0.21  0.21  0.21
# 191  Virgin Islands, U.S.  2.06  2.05  2.06  2.09  2.16  2.04  2.02  2.01
# 192                 Yemen  0.23  0.23  0.23  0.23  0.23  0.23  0.23  0.23
# 193                Zambia  0.55  0.57  0.59  0.60  0.61  0.62  0.63  0.63
# 194              Zimbabwe  1.10  1.05  1.06  1.09  1.16  1.30  1.34  1.44
#
#      1998  ...  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017
# 0    0.39  ...  0.34  0.34  0.33  0.32  0.32  0.32  0.31  0.31  0.31  0.31
# 1    1.48  ...  1.31  1.25  1.18  1.21  1.22  1.23  1.25  1.25  1.24  1.23
# 2    0.24  ...  0.26  0.26  0.26  0.26  0.25  0.25  0.24  0.24  0.23  0.23
# 3    0.80  ...  0.53  0.53  0.54  0.54  0.53  0.55  0.55  0.56  0.57  0.57
# 4    1.05  ...  0.88  0.87  0.86  0.83  0.82  0.82  0.82  0.81  0.81  0.81
# ..    ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 190  0.21  ...  0.21  0.21  0.21  0.20  0.20  0.20  0.20  0.20  0.20  0.20
# 191  2.04  ...  2.05  2.06  2.16  2.20  2.21  2.27  2.29  2.34  2.33  2.33
# 192  0.23  ...  0.24  0.24  0.24  0.24  0.23  0.23  0.23  0.23  0.23  0.24
# 193  0.63  ...  0.54  0.54  0.54  0.53  0.52  0.51  0.50  0.50  0.49  0.49
# 194  1.59  ...  2.04  1.97  1.88  1.77  1.68  1.61  1.55  1.52  1.49  1.47
#
# [195 rows x 29 columns]

# %%
# PERCENTAGE SUICIDE BY FIREARM
byfirearm_pct_df = suicide_rate_df.filter(['Country Name'], axis=1).reset_index(drop=True)  # create heading column
Time = suicide_rate_df.keys()

for i in range(1,len(Time)):
    byfirearm_pct_df[Time[i]]=(100*byfirearm_rate_df[Time[i]]/suicide_rate_df[Time[i]]).round(2)
    
byfirearm_pct_df.head()
# Out:
#      Country Name   1990   1991   1992   1993   1994   1995   1996   1997  \
# 0     Afghanistan   6.49   6.41   6.45   6.30   6.29   6.20   6.17   6.08
# 1         Albania  23.42  23.90  24.14  24.66  25.21  26.20  27.61  30.48
# 2         Algeria   5.01   4.95   5.11   5.00   5.00   5.12   5.01   5.11
# 3  American Samoa  14.55  14.51  14.48  14.34  14.36  14.41  14.46  14.73
# 4         Andorra   9.59   9.43   9.39   9.23   9.15   9.11   9.02   8.57
#
#     1998  ...   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 0   5.97  ...   5.93   6.04   5.96   5.86   5.94   5.98   5.85   5.86   5.88
# 1  32.31  ...  22.74  22.01  20.63  21.04  21.18  21.17  21.26  21.22  21.09
# 2   5.04  ...   5.49   5.57   5.66   5.70   5.57   5.61   5.41   5.47   5.39
# 3  13.94  ...   9.52   9.48   9.49   9.36   9.06   9.27   9.15   9.08   9.18
# 4   8.52  ...   7.87   7.84   7.83   7.76   7.71   7.77   7.95   7.93   7.93
#
#     2017
# 0   5.90
# 1  20.99
# 2   5.48
# 3   9.11
# 4   7.91
#
# [5 rows x 29 columns]

# %%
#suicide_rate_df.sort_values(by='1990', ascending=False)
print(byfirearm_pct_df.sort_values(by='1990', ascending=False)['Country Name'].head())
# Out:
# 185    United States
# 186          Uruguay
# 7          Argentina
# 37          Colombia
# 189        Venezuela
# Name: Country Name, dtype: object

# %%
# Generate bar plot for Percentage Of Suicide by Firearm 1990
SuicideByFirearm1990 = byfirearm_pct_df.filter(['Country Name','1990'], axis=1).set_index('Country Name')
SuicideByFirearm1990.sort_values(by='1990', ascending=False,inplace=True)
SuicideByFirearm1990 = SuicideByFirearm1990.iloc[:15,0]
SuicideByFirearm1990.plot(kind="bar", figsize=(15,5), legend = False, rot = 0, grid = True,
                          title ="Percentage Of Suicide by Firearm 1990")
plt.savefig('SuicideByFirearm1990.png')

# %%
# Generate a horisontal bar plot  
SuicideByFirearm1990 = byfirearm_pct_df.filter(['Country Name','2017'], axis=1).set_index('Country Name')
SuicideByFirearm1990.sort_values(by='2017', ascending=False,inplace=True)
SuicideByFirearm1990 = SuicideByFirearm1990.iloc[:15,0]
SuicideByFirearm1990.plot(kind="bar", figsize=(15,5), legend = False, rot = 0, grid = True,
                          title ="Percentage Of Death by Firearm 2017")
plt.savefig('SuicideByFirearm2017.png')

# %%
# SUICIDE BY REGION (definision please see http://ghdx.healthdata.org/countries)
# retrieve file and create base dataframe for Suicide for all region ; CauseNo = 718 for selfharm/suicide, MetricId = 3 Rate
file2 = pd.read_csv("IHME-GBD_2017_DATA-3a91bc48-1.csv")
reg_df = file2[(file2["sex_id"]==3) & (file2["metric_id"]==3) & (file2["measure_id"]==1) & (file2["cause_id"] == 721)].round(2)

#create matrix
region_df = matrix_maker_function(reg_df ,'location_name','year')
region_df.rename(columns={"location_name":"Region"}, inplace=True)
region_df.head(1)
# Out:
#    Region  1990  1991  1992  1993  1994  1995  1996  1997  1998  ...  2008  \
# 0  Africa  0.54  0.54  0.54  0.55  0.55  0.56  0.56  0.57  0.58  ...  0.54
#
#    2009  2010  2011  2012  2013  2014  2015  2016  2017
# 0  0.53  0.53  0.52  0.51   0.5  0.49  0.49  0.49  0.49
#
# [1 rows x 29 columns]

# %%
# GDP PPP PerPopulation MATRIX
# Read file
file1 = pd.read_csv("gdp_ppp_pop.csv", encoding='cp1252')
gdp_temp_df = file1.drop(file1.columns[1:34], axis=1).round(0)
gdp_temp_df = gdp_temp_df.drop(gdp_temp_df.columns[29], axis=1)

print(gdp_temp_df.shape)    #check shape and heading
gdp_temp_df.head(1)
# Out:
# (265, 29)
#   Country Name     1990     1991     1992     1993     1994     1995     1996  \
# 0        Aruba  35177.0  36525.0  36626.0  36988.0  37833.0  37046.0  36190.0
#
#       1997     1998  ...     2008     2009     2010     2011     2012  \
# 0  37720.0  37666.0  ...  37963.0  33937.0  32617.0  33617.0  32990.0
#
#       2013     2014     2015     2016     2017
# 0  34176.0  34261.0  33921.0  33678.0  33966.0
#
# [1 rows x 29 columns]

# %%
# DATA CLEANING : Checking if names in the key column of the two matrix are the same and list all the difference 
df1 = suicide_rate_df
df2 = gdp_temp_df
common1 = pd.merge(df1,df2,on=['Country Name'], how='outer')
#check for data that not in each other list for name spelling difference
outcast1_df = common1[~common1['Country Name'].isin(df1['Country Name'])].filter(['Country Name'], axis=1).reset_index(drop=True)
outcast2_df = common1[~common1['Country Name'].isin(df2['Country Name'])].filter(['Country Name'], axis=1).reset_index(drop=True)
outcast_df = pd.concat([outcast1_df,outcast2_df], ignore_index=True, axis=1)
outcast_df.head()
# Out:
#                                 0                                 1
# 0                           Aruba                            Brunei
# 1                      Arab World                        Cape Verde
# 2                    Bahamas, The                             Congo
# 3               Brunei Darussalam  Democratic Republic of the Congo
# 4  Central Europe and the Baltics                             Egypt

# %%
#change the name to make the key column align
gdp_ed_df = gdp_temp_df.replace(['Brunei Darussalam','Cabo Verde', 'Congo, Rep.', 'Congo, Dem. Rep.','Egypt, Arab Rep.',
                            'Micronesia, Fed. Sts.','Iran, Islamic Rep.','Kyrgyz Republic','Lao PDR','North Macedonia',
                            'Korea, Dem. People’s Rep.','West Bank and Gaza','St. Lucia','St. Vincent and the Grenadines',
                            'Slovak Republic','Korea, Rep.','Eswatini','Syrian Arab Republic','Bahamas, The','Gambia, The',
                            'Venezuela, RB','Virgin Islands (U.S.)','Yemen, Rep.'],                             
                           ['Brunei', 'Cape Verde', 'Congo', 'Democratic Republic of the Congo','Egypt',
                            'Federated States of Micronesia','Iran','Kyrgyzstan','Laos','Macedonia','North Korea',
                            'Palestine','Saint Lucia','Saint Vincent and the Grenadines','Slovakia',
                            'South Korea','Swaziland','Syria','The Bahamas','The Gambia','Venezuela',
                            'Virgin Islands, U.S.','Yemen'])

# %%
#double check if data is already clean as expected
common = pd.merge(df1,gdp_ed_df,on=['Country Name'], how='outer')
outcast_ed1_df = common[~common['Country Name'].isin(df1['Country Name'])].filter(['Country Name'], axis=1).reset_index(drop=True)
outcast_ed3_df = common[~common['Country Name'].isin(gdp_ed_df['Country Name'])].filter(['Country Name'], axis=1).reset_index(drop=True)
outcast_ed_df = pd.concat([outcast_ed1_df,outcast_ed3_df], ignore_index=True, axis=1)
outcast_ed_df
# Out:
#                                  0    1
# 0                            Aruba  NaN
# 1                       Arab World  NaN
# 2   Central Europe and the Baltics  NaN
# 3                  Channel Islands  NaN
# 4           Caribbean small states  NaN
# ..                             ...  ...
# 65                          Tuvalu  NaN
# 66             Upper middle income  NaN
# 67          British Virgin Islands  NaN
# 68                           World  NaN
# 69                          Kosovo  NaN
#
# [70 rows x 2 columns]

# %%
# create a matrix similar to suicide_df gor GDP PPP
gdp_df = suicide_rate_df.filter(['Country Name'], axis=1).reset_index(drop=True)
gdp_df = pd.merge(gdp_df,gdp_ed_df,on=['Country Name'], how='inner')
gdp_df
# Out:
#              Country Name    1990    1991    1992    1993    1994    1995  \
# 0             Afghanistan     NaN     NaN     NaN     NaN     NaN     NaN
# 1                 Albania  4948.0  3584.0  3347.0  3689.0  4020.0  4584.0
# 2                 Algeria  8607.0  8297.0  8250.0  7900.0  7668.0  7809.0
# 3          American Samoa     NaN     NaN     NaN     NaN     NaN     NaN
# 4                 Andorra     NaN     NaN     NaN     NaN     NaN     NaN
# ..                    ...     ...     ...     ...     ...     ...     ...
# 190               Vietnam  1673.0  1736.0  1848.0  1958.0  2092.0  2253.0
# 191  Virgin Islands, U.S.     NaN     NaN     NaN     NaN     NaN     NaN
# 192                 Yemen     NaN     NaN     NaN     NaN     NaN     NaN
# 193                Zambia  2193.0  2136.0  2048.0  2136.0  1905.0  1911.0
# 194              Zimbabwe  3441.0  3547.0  3162.0  3140.0  3378.0  3339.0
#
#        1996    1997    1998  ...     2008     2009     2010     2011     2012  \
# 0       NaN     NaN     NaN  ...   1588.0   1882.0   2094.0   2038.0   2220.0
# 1    5032.0  4511.0  4940.0  ...  10161.0  10573.0  11019.0  11330.0  11510.0
# 2    7988.0  7946.0  8227.0  ...  10625.0  10611.0  10796.0  10902.0  11055.0
# 3       NaN     NaN     NaN  ...      NaN      NaN      NaN      NaN      NaN
# 4       NaN     NaN     NaN  ...      NaN      NaN      NaN      NaN      NaN
# ..      ...     ...     ...  ...      ...      ...      ...      ...      ...
# 190  2426.0  2587.0  2702.0  ...   4628.0   4830.0   5089.0   5352.0   5574.0
# 191     NaN     NaN     NaN  ...      NaN      NaN      NaN      NaN      NaN
# 192     NaN     NaN     NaN  ...      NaN      NaN      NaN      NaN      NaN
# 193  1977.0  1997.0  1935.0  ...   2751.0   2921.0   3129.0   3205.0   3343.0
# 194  3644.0  3705.0  3782.0  ...   1800.0   1993.0   2353.0   2646.0   3035.0
#
#         2013     2014     2015     2016     2017
# 0     2264.0   2249.0   2213.0   2201.0   2203.0
# 1    11646.0  11877.0  12176.0  12600.0  13094.0
# 2    11139.0  11329.0  11511.0  11638.0  11551.0
# 3        NaN      NaN      NaN      NaN      NaN
# 4        NaN      NaN      NaN      NaN      NaN
# ..       ...      ...      ...      ...      ...
# 190   5815.0   6098.0   6438.0   6768.0   7156.0
# 191      NaN      NaN      NaN      NaN      NaN
# 192      NaN      NaN      NaN      NaN      NaN
# 193   3404.0   3454.0   3448.0   3471.0   3485.0
# 194   3041.0   3059.0   3062.0   3038.0   3134.0
#
# [195 rows x 29 columns]

# %%
file4 = pd.read_csv("IHME-GBD_2017_DATA-0b0c808a-1.csv")

file4_df = file4[(file4["sex_id"]==3) & (file4["metric_id"]==1)  & (file4["location_name"]=="Canada") & (file4["measure_id"]==1)]
file4_df.head(3)
# Out:
#      measure_id measure_name  location_id location_name  sex_id sex_name  \
# 98            1       Deaths          101        Canada       3     Both
# 104           1       Deaths          101        Canada       3     Both
# 128           1       Deaths          101        Canada       3     Both
#
#      age_id  age_name  cause_id                cause_name  metric_id  \
# 98       22  All Ages       386  Nutritional deficiencies          1
# 104      22  All Ages       410                 Neoplasms          1
# 128      22  All Ages       491   Cardiovascular diseases          1
#
#     metric_name  year           val         upper         lower
# 98       Number  1990    143.542463    151.471457    136.201487
# 104      Number  1990  55822.485354  56518.770893  54416.565032
# 128      Number  1990  73181.597028  74116.468628  72367.591718

# %%
death_cause_df = pd.pivot_table(file4_df, index=["cause_name"],values=["val"],columns=["year"])
death_cause_df = pd.DataFrame(death_cause_df.to_records())
death_cause_df.columns = [hdr.replace("('val', ", "").replace(")", "") \
                     for hdr in death_cause_df.columns]
death_cause_df = death_cause_df.sort_values(by='2017', ascending=True).round()

# %%
# Generate a horisontal bar plot  
CauseOfDeath = death_cause_df.filter(['cause_name','2017'], axis=1).set_index('cause_name')
CauseOfDeath.plot(kind="barh", figsize=(10,5), legend = False, rot = 0, grid = True, title ="Cause Of Death in Canada in 2017")

# %%
# SUICIDE BY AGE
# retrieve file 
file3 = pd.read_csv("IHME-GBD_2017_DATA-c50a2fa5-1.csv")

# create base dataframe of cause of death for each age group in 2017 
# location=global location_id=1, MetricId = 1 Number, sex_id = 3 both, measure_id = 1 death , year = 2017
age_temp_df = file3[(file3["location_id"]==1) & (file3["sex_id"]==3) & (file3["metric_id"]==1) & 
               (file3["measure_id"]==1) & (file3["year"]==2017) ].round()
#create matrix
age_df = matrix_maker_function(age_temp_df ,'cause_name','age_name')

#clean the matrix

age_df.drop([19], axis=0,inplace=True)
age_df = age_5_df.fillna(0)
age_df.head(1)
# Out:
#    cause_name  '10 to 14'  '15 to 19'  '20 to 24'  '25 to 29'  '30 to 34'  \
# 0  All causes    319630.0    516509.0    709782.0    838974.0   1006999.0
#
#    '35 to 39'  '40 to 44'  '45 to 49'  '5 to 9'  ...  '55 to 59'  '60 to 64'  \
# 0   1164779.0   1448494.0   1928487.0  412113.0  ...   3112789.0   4245092.0
#
#    '65 to 69'  '70 to 74'  '75 to 79'  '80 to 84'  '85 to 89'  '90 to 94'  \
# 0   5018790.0   5272671.0   5964171.0   6441449.0   5311646.0   3032676.0
#
#    '95 plus'  'Under 5'
# 0  1187152.0  5391562.0
#
# [1 rows x 21 columns]

# %%
age_5_df = age_df.drop(["'5 to 9'","'Under 5'"], axis=1)
age_5_df.insert(1, "'5 to 9'", age_df["'5 to 9'"])
age_5_df.insert(1, "'Under 5'", age_df["'Under 5'"])
age_5_df.head(2)
# Out:
#                 cause_name  'Under 5'  '5 to 9'  '10 to 14'  '15 to 19'  \
# 0               All causes  5391562.0  412113.0    319630.0    516509.0
# 1  Cardiovascular diseases    30091.0    6671.0      8959.0     25552.0
#
#    '20 to 24'  '25 to 29'  '30 to 34'  '35 to 39'  '40 to 44'  ...  \
# 0    709782.0    838974.0   1006999.0   1164779.0   1448494.0  ...
# 1     43557.0     70020.0    120733.0    183634.0    308412.0  ...
#
#    '50 to 54'  '55 to 59'  '60 to 64'  '65 to 69'  '70 to 74'  '75 to 79'  \
# 0   2621964.0   3112789.0   4245092.0   5018790.0   5272671.0   5964171.0
# 1    787266.0   1018640.0   1493872.0   1852327.0   1986637.0   2427618.0
#
#    '80 to 84'  '85 to 89'  '90 to 94'  '95 plus'
# 0   6441449.0   5311646.0   3032676.0  1187152.0
# 1   2713182.0   2327705.0   1348551.0   531444.0
#
# [2 rows x 21 columns]

# %%
(age_5_df.iloc[1,:])+(age_5_df.iloc[0,:])
# Out:
# cause_name    Cardiovascular diseasesAll causes
# 'Under 5'                           5.42165e+06
# '5 to 9'                                 418784
# '10 to 14'                               328589
# '15 to 19'                               542061
# '20 to 24'                               753339
# '25 to 29'                               908994
# '30 to 34'                          1.12773e+06
# '35 to 39'                          1.34841e+06
# '40 to 44'                          1.75691e+06
# '45 to 49'                          2.43456e+06
# '50 to 54'                          3.40923e+06
# '55 to 59'                          4.13143e+06
# '60 to 64'                          5.73896e+06
# '65 to 69'                          6.87112e+06
# '70 to 74'                          7.25931e+06
# '75 to 79'                          8.39179e+06
# '80 to 84'                          9.15463e+06
# '85 to 89'                          7.63935e+06
# '90 to 94'                          4.38123e+06
# '95 plus'                            1.7186e+06
# dtype: object

# %%
age_10_df = age_5_df.filter(['cause_name'], axis=1)
age_10_df["0 to 9"] = age_5_df["'Under 5'"] + age_5_df["'5 to 9'"]
age_10_df["10 to 19"] = age_5_df["'10 to 14'"] + age_5_df["'15 to 19'"]
age_10_df["20 to 29"] = age_5_df["'20 to 24'"] + age_5_df["'25 to 29'"]
age_10_df["30 to 39"] = age_5_df["'30 to 34'"] + age_5_df["'35 to 39'"]
age_10_df["40 to 49"] = age_5_df["'40 to 44'"] + age_5_df["'45 to 49'"]
age_10_df["50 to 59"] = age_5_df["'50 to 54'"] + age_5_df["'55 to 59'"]
age_10_df["60 to 69"] = age_5_df["'60 to 64'"] + age_5_df["'65 to 69'"]
age_10_df["70 to 79"] = age_5_df["'70 to 74'"] + age_5_df["'75 to 79'"]
age_10_df["80 to 89"] = age_5_df["'80 to 84'"] + age_5_df["'85 to 89'"]
age_10_df["90 plus"] = age_5_df["'90 to 94'"] + age_5_df["'95 plus'"]
age_10_df
# Out:
#                                       cause_name     0 to 9  10 to 19  \
# 0                                     All causes  5803675.0  836139.0
# 1                        Cardiovascular diseases    36762.0   34511.0
# 2                   Chronic respiratory diseases    13967.0    9758.0
# 3                   Diabetes and kidney diseases    19575.0   16775.0
# 4                             Digestive diseases    50776.0   26634.0
# 5                             Enteric infections   661215.0   72893.0
# 6   HIV/AIDS and sexually transmitted infections   211232.0   58284.0
# 7                         Interpersonal violence    16149.0   42871.0
# 8                Maternal and neonatal disorders  1783770.0   18251.0
# 9                               Mental disorders        1.0      25.0
# 10                     Musculoskeletal disorders      515.0    2472.0
# 11       Neglected tropical diseases and malaria   417967.0   44215.0
# 12                                     Neoplasms    82418.0   64703.0
# 13                        Neurological disorders    23162.0   17771.0
# 14                      Nutritional deficiencies   151249.0    4085.0
# 15                     Other infectious diseases   453037.0   41392.0
# 16               Other non-communicable diseases   608104.0   35659.0
# 17       Respiratory infections and tuberculosis   906878.0   51367.0
# 18                                     Self-harm        0.0   51397.0
# 20                Skin and subcutaneous diseases     6615.0    1486.0
# 21                       Substance use disorders        0.0    4536.0
# 22                            Transport injuries    87814.0  111979.0
# 23                        Unintentional injuries   249346.0   98603.0
#
#      20 to 29   30 to 39   40 to 49   50 to 59   60 to 69    70 to 79  \
# 0   1548756.0  2171778.0  3376981.0  5734753.0  9263882.0  11236842.0
# 1    113577.0   304367.0   814489.0  1805906.0  3346199.0   4414255.0
# 2     20463.0    38443.0    97877.0   286497.0   717935.0   1184856.0
# 3     38159.0    68496.0   160551.0   353822.0   587098.0    638141.0
# 4     62532.0   137952.0   260849.0   400119.0   483947.0    447561.0
# 5     53250.0    46908.0    54146.0    85590.0   163700.0    269760.0
# 6    132388.0   273691.0   238021.0   106623.0    38137.0     12405.0
# 7    115357.0    92422.0    60549.0    39413.0    22988.0     12525.0
# 8     71707.0    67997.0    33934.0     1750.0        0.0         0.0
# 9        86.0      100.0      114.0        0.0        0.0         0.0
# 10     4462.0     5702.0     8295.0    10957.0    22513.0     29359.0
# 11    40330.0    36724.0    38359.0    45518.0    46390.0     35635.0
# 12   103556.0   244737.0   665040.0  1483764.0  2478572.0   2388080.0
# 13    21914.0    22643.0    30647.0    60317.0   184202.0    587581.0
# 14     4068.0     4444.0     6654.0    10772.0    17572.0     25578.0
# 15    37344.0    40233.0    45899.0    53668.0    56813.0     54073.0
# 16    35673.0    34737.0    42566.0    58518.0    84293.0     96207.0
# 17   108146.0   169409.0   236042.0   357399.0   479380.0    583335.0
# 18   144495.0   139441.0   126557.0   117464.0    95656.0     68103.0
# 20     1687.0     3279.0     5566.0    10268.0    15406.0     21110.0
# 21    34283.0    64046.0    77018.0    74900.0    51503.0     26291.0
# 22   233733.0   208358.0   197407.0   182814.0   152231.0     97776.0
# 23   129537.0   143033.0   163185.0   181106.0   214707.0    241745.0
#
#       80 to 89    90 plus
# 0   11753095.0  4219828.0
# 1    5040887.0  1879995.0
# 2    1222556.0   321846.0
# 3     553780.0   174803.0
# 4     383481.0   123833.0
# 5     290871.0    67659.0
# 6       2362.0      441.0
# 7       2580.0      493.0
# 8          0.0        0.0
# 9          0.0        0.0
# 10     27741.0     9254.0
# 11     12847.0     2075.0
# 12   1677172.0   368204.0
# 13   1332826.0   813100.0
# 14     30017.0    15557.0
# 15     39930.0     8105.0
# 16    108420.0    49091.0
# 17    616660.0   243723.0
# 18     42770.0     7940.0
# 20     23805.0    11063.0
# 21     14898.0     4072.0
# 22     52977.0     9916.0
# 23    275239.0   108370.0

# %%
# Generate a horisontal bar plot for Cause Of Death in young people
DeathByAge = age_5_df.filter(['cause_name','10 to 14','20 to 29','30 to 39','40 to 49'], axis=1)
DeathByAge = DeathByAge.drop([0], axis=0).set_index('cause_name')
DeathByAge = DeathByAge.transpose()
DeathByAge.plot(kind="barh", figsize=(15,10), legend = True, rot = 0, grid = True, 
                title ="Cause Of Death in young people in 2017")

# %%
# Generate a horisontal bar plot for Cause Of Death in young people
DeathByAge = age_10_df.filter(['cause_name','10 to 19','20 to 29','30 to 39','40 to 49'], axis=1)
DeathByAge = DeathByAge.drop([0], axis=0).set_index('cause_name')
DeathByAge = DeathByAge.transpose()
DeathByAge.plot(kind="barh", figsize=(10,12), legend = True, rot = 0, grid = True, 
                title ="Cause Of Death in young people in 2017")
