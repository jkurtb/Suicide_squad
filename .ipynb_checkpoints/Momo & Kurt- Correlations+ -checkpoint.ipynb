# %%
# Dependencies
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
# Load/Read World Happiness Data 
HappinessIndex_summary = "Data sets/From Vivi/HappinessIndex.csv"
HappinessIndex = pd.read_csv(HappinessIndex_summary)
HappinessIndex.set_index('Country name', inplace=True)
HappinessIndex.head(3)
# Out:
#              Code  year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Afghanistan   AFG  2008         3.72                7.14            0.45
# Afghanistan   AFG  2009         4.40                7.31            0.55
# Afghanistan   AFG  2010         4.76                7.42            0.54
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Afghanistan                               50.8                          0.72
# Afghanistan                               51.2                          0.68
# Afghanistan                               51.6                          0.60
#
#               Generosity  Perceptions of corruption
# Country name
# Afghanistan         0.18                       0.88
# Afghanistan         0.20                       0.85
# Afghanistan         0.13                       0.71

# %%
# Filter Y2007 and sort by greatest GDP
HappinessIndex = HappinessIndex.loc[HappinessIndex['year'] == 2017]
HappinessIndex = HappinessIndex.sort_values('Log GDP per capita', ascending=False) 
HappinessIndex.head(1)
# Out:
#              Code  year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Luxembourg    LUX  2017         7.06               11.44            0.91
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Luxembourg                                72.6                           0.9
#
#               Generosity  Perceptions of corruption
# Country name
# Luxembourg          0.05                       0.33

# %%
# Check countries 
LowHappy_HighGDP = HappinessIndex[(HappinessIndex["Life Ladder"]<=6) & (HappinessIndex["Log GDP per capita"]>=10)] 
# LowHappy_HighGDP.to_csv('LowHappy_HighGDP.csv')
LowHappy_HighGDP.head(20)
# Out:
#              Code  year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Japan         JPN  2017         5.91               10.57            0.88
# South Korea   KOR  2017         5.87               10.49            0.81
# Estonia       EST  2017         5.94               10.31            0.94
# Portugal      PRT  2017         5.71               10.24            0.90
# Turkey        TUR  2017         5.61               10.13            0.88
# Latvia        LVA  2017         5.98               10.13            0.90
# Russia        RUS  2017         5.58               10.12            0.90
# Greece        GRC  2017         5.15               10.11            0.75
# Kazakhstan    KAZ  2017         5.88               10.09            0.91
# Croatia       HRV  2017         5.34               10.04            0.77
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Japan                                     74.9                          0.85
# South Korea                               73.3                          0.54
# Estonia                                   68.4                          0.86
# Portugal                                  72.2                          0.91
# Turkey                                    66.4                          0.64
# Latvia                                    66.5                          0.70
# Russia                                    63.9                          0.73
# Greece                                    72.2                          0.44
# Kazakhstan                                64.0                          0.75
# Croatia                                   69.6                          0.72
#
#               Generosity  Perceptions of corruption
# Country name
# Japan              -0.21                       0.66
# South Korea         0.01                       0.85
# Estonia            -0.10                       0.67
# Portugal           -0.17                       0.88
# Turkey             -0.24                       0.67
# Latvia             -0.15                       0.80
# Russia             -0.15                       0.86
# Greece             -0.29                       0.87
# Kazakhstan         -0.04                       0.76
# Croatia            -0.10                       0.89

# %% [markdown]
# Outliers (Low Happiness, High GDP): South Korea, Russia, Croatia, Hungary

# %%
# Check countries 
HighHappy_LowGDP = HappinessIndex[(HappinessIndex["Life Ladder"]>=6) & (HappinessIndex["Log GDP per capita"]<=9.5)] 
# LowHappy_HighGDP.to_csv('LowHappy_HighGDP.csv')
HighHappy_LowGDP.head(20)
# Out:
#              Code  year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Colombia      COL  2017         6.16                9.49            0.91
# Kosovo        KXK  2017         6.15                9.19            0.79
# Guatemala     GTM  2017         6.33                8.91            0.83
# El Salvador   SLV  2017         6.34                8.89            0.83
# Uzbekistan    UZB  2017         6.42                8.71            0.94
# Nicaragua     NIC  2017         6.48                8.55            0.84
# Honduras      HND  2017         6.02                8.40            0.84
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Colombia                                  67.4                          0.84
# Kosovo                                     NaN                          0.86
# Guatemala                                 64.5                          0.91
# El Salvador                               65.8                          0.76
# Uzbekistan                                64.8                          0.99
# Nicaragua                                 67.2                          0.92
# Honduras                                  67.0                          0.90
#
#               Generosity  Perceptions of corruption
# Country name
# Colombia           -0.16                       0.88
# Kosovo              0.12                       0.93
# Guatemala          -0.06                       0.80
# El Salvador        -0.17                       0.78
# Uzbekistan          0.12                       0.46
# Nicaragua           0.01                       0.67
# Honduras            0.08                       0.78

# %% [markdown]
# Outliers (Low GDP, High Happy): All

# %%
HappinessIndex["ColC"] = HappinessIndex["Log GDP per capita"].subtract(HappinessIndex["Life Ladder"], fill_value=0)
HappinessIndex.sort_values('ColC', ascending=False)
# Out:
#              Code  year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Botswana      BWA  2017         3.50                9.69            0.77
# Egypt         EGY  2017         3.93                9.28            0.64
# Iraq          IRQ  2017         4.46                9.67            0.70
# Tunisia       TUN  2017         4.12                9.30            0.72
# Iran          IRN  2017         4.72                9.86            0.71
# ...           ...   ...          ...                 ...             ...
# Honduras      HND  2017         6.02                8.40            0.84
# Uzbekistan    UZB  2017         6.42                8.71            0.94
# Niger         NER  2017         4.62                6.83            0.58
# Tajikistan    TJK  2017         5.83                7.98            0.66
# Nicaragua     NIC  2017         6.48                8.55            0.84
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Botswana                                  58.2                          0.82
# Egypt                                     61.4                          0.59
# Iraq                                      59.6                          0.63
# Tunisia                                   66.6                          0.48
# Iran                                      65.7                          0.73
# ...                                        ...                           ...
# Honduras                                  67.0                          0.90
# Uzbekistan                                64.8                          0.99
# Niger                                     53.0                          0.68
# Tajikistan                                63.8                          0.83
# Nicaragua                                 67.2                          0.92
#
#               Generosity  Perceptions of corruption  ColC
# Country name
# Botswana           -0.25                       0.73  6.19
# Egypt              -0.16                        NaN  5.35
# Iraq               -0.03                       0.76  5.21
# Tunisia            -0.23                       0.87  5.18
# Iran                0.19                       0.71  5.14
# ...                  ...                        ...   ...
# Honduras            0.08                       0.78  2.38
# Uzbekistan          0.12                       0.46  2.29
# Niger              -0.02                       0.78  2.21
# Tajikistan          0.12                       0.72  2.15
# Nicaragua           0.01                       0.67  2.07
#
# [121 rows x 10 columns]

# %%
# df = HappinessIndex.
HappinessIndex['total']=HappinessIndex.iloc[:2:3].difference()
# Out:
# ---------------------------------------------------------------
# AttributeError                Traceback (most recent call last)
# <ipython-input-18-79845d311341> in <module>
#       2
#       3
# ----> 4 HappinessIndex['total']=HappinessIndex.iloc[:4:10].difference()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'difference'
