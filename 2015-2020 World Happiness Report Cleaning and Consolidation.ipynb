# %%
# Dependencies
import pandas as pd
import csv

# %% [markdown]
# ### Clean Datasets Derived from the Yearly World Happiness Report

# %%
# Load/ happiness_2015
happiness_2015 = "Data sets/Raw Data/Happiness Score/happiness_2015.csv"
k_happiness_2015 = pd.read_csv(happiness_2015)
k_happiness_2015.head(1)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738

# %%
# Rename Columns with Y2015 Data Identifiers 
happy_2015 = k_happiness_2015.rename(columns={
                                    'Happiness Rank': '2015 Happiness Rank', 'Happiness Score': '2015 Happiness Score', 'Region': '2015 Region',
                                    'Standard Error': '2015 Standard Error', 'Economy (GDP per Capita)': '2015 Economy (GDP per Capita)',
                                    'Family': '2015 Family', 'Health (Life Expectancy)': '2015 Health (Life Expectancy)',
                                    'Freedom': '2015 Freedom', 'Trust (Government Corruption)': '2015 Trust (Government Corruption)',
                                    'Generosity': '2015 Generosity', 'Dystopia Residual': '2015 Dystopia Residual'})
happy_2015.head(1)
# Out:
#        Country     2015 Region  2015 Happiness Rank  2015 Happiness Score  \
# 0  Switzerland  Western Europe                    1                 7.587
#
#    2015 Standard Error  2015 Economy (GDP per Capita)  2015 Family  \
# 0              0.03411                        1.39651      1.34951
#
#    2015 Health (Life Expectancy)  2015 Freedom  \
# 0                        0.94143       0.66557
#
#    2015 Trust (Government Corruption)  2015 Generosity  2015 Dystopia Residual
# 0                             0.41978          0.29678                 2.51738

# %%
# Load/Read happiness_2016
happiness_2016 = "Data sets/Raw Data/Happiness Score/happiness_2016.csv"
k_happiness_2016 = pd.read_csv(happiness_2016)
k_happiness_2016.head(1)
# Out:
#    Country          Region  Happiness Rank  Happiness Score  \
# 0  Denmark  Western Europe               1            7.526
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                       7.46                      7.592
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939

# %%
# Rename Columns with Y2016 Data Identifiers 
happy_2016 = k_happiness_2016.rename(columns={
                                    'Happiness Rank': '2016 Happiness Rank', 'Happiness Score': '2016 Happiness Score', 'Region': '2016 Region',
                                    'Lower Confidence Interval': '2016 Lower Confidence Interval', 'Upper Confidence Interval': '2016 Upper Confidence Interval',
                                    'Economy (GDP per Capita)': '2016 Economy (GDP per Capita)', 'Family': '2016 Family', 'Health (Life Expectancy)': '2016 Health (Life Expectancy)',
                                    'Freedom': '2016 Freedom', 'Trust (Government Corruption)': '2016 Trust (Government Corruption)',
                                    'Generosity': '2016 Generosity', 'Dystopia Residual': '2016 Dystopia Residual'})
happy_2016.head(1)
# Out:
#    Country     2016 Region  2016 Happiness Rank  2016 Happiness Score  \
# 0  Denmark  Western Europe                    1                 7.526
#
#    2016 Lower Confidence Interval  2016 Upper Confidence Interval  \
# 0                            7.46                           7.592
#
#    2016 Economy (GDP per Capita)  2016 Family  2016 Health (Life Expectancy)  \
# 0                        1.44178      1.16374                        0.79504
#
#    2016 Freedom  2016 Trust (Government Corruption)  2016 Generosity  \
# 0       0.57941                             0.44453          0.36171
#
#    2016 Dystopia Residual
# 0                 2.73939

# %%
# Load/Read happiness_2017
happiness_2017 = "Data sets/Raw Data/Happiness Score/happiness_2017.csv"
k_happiness_2017 = pd.read_csv(happiness_2017)
k_happiness_2017.head(1)
# Out:
#   Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0  Norway               1            7.537      7.594445     7.479556
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027

# %%
# Rename Columns with Y2017 Data Identifiers 
happy_2017 = k_happiness_2017.rename(columns={
                                    'Happiness.Rank': '2017 Happiness Rank', 'Happiness.Score': '2017 Happiness Score', 'Whisker.high': '2017 Whisker.high', 
                                    'Whisker.low': '2017 Whisker.low', 'Economy..GDP.per.Capita.': '2017 Economy (GDP per Capita)', 'Family': '2017 Family', 
                                    'Health..Life.Expectancy.': '2017 Health (Life Expectancy)', 'Freedom': '2017 Freedom', 'Trust..Government.Corruption.': '2017 Trust (Government Corruption)', 
                                    'Generosity': '2017 Generosity', 'Dystopia.Residual': '2017 Dystopia Residual'})
happy_2017.head(1)
# Out:
#   Country  2017 Happiness Rank  2017 Happiness Score  2017 Whisker.high  \
# 0  Norway                    1                 7.537           7.594445
#
#    2017 Whisker.low  2017 Economy (GDP per Capita)  2017 Family  \
# 0          7.479556                       1.616463     1.533524
#
#    2017 Health (Life Expectancy)  2017 Freedom  2017 Generosity  \
# 0                       0.796667      0.635423         0.362012
#
#    2017 Trust (Government Corruption)  2017 Dystopia Residual
# 0                            0.315964                2.277027

# %%
# Load/Read happiness_2018
happiness_2018 = "Data sets/Raw Data/Happiness Score/happiness_2018.csv"
k_happiness_2018 = pd.read_csv(happiness_2017)
k_happiness_2018.head(1)
# Out:
#   Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0  Norway               1            7.537      7.594445     7.479556
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027

# %%
# Rename Columns with Y2018 Data Identifiers 
happy_2018 = k_happiness_2018.rename(columns={
                                    'Happiness.Rank': '2018 Happiness Rank', 'Happiness.Score': '2018 Happiness Score', 'Whisker.high': '2018 Whisker.high', 
                                    'Whisker.low': '2018 Whisker.low', 'Economy..GDP.per.Capita.': '2018 Economy (GDP per Capita)', 'Family': '2018 Family', 
                                     'Health..Life.Expectancy.': '2018 Health (Life Expectancy)', 'Freedom': '2018 Freedom', 'Trust..Government.Corruption.': '2018 Trust (Government Corruption)',
                                    'Generosity': '2018 Generosity', 'Dystopia.Residual': '2018 Dystopia Residual'})
happy_2018.head(1)
# Out:
#   Country  2018 Happiness Rank  2018 Happiness Score  2018 Whisker.high  \
# 0  Norway                    1                 7.537           7.594445
#
#    2018 Whisker.low  2018 Economy (GDP per Capita)  2018 Family  \
# 0          7.479556                       1.616463     1.533524
#
#    2018 Health (Life Expectancy)  2018 Freedom  2018 Generosity  \
# 0                       0.796667      0.635423         0.362012
#
#    2018 Trust (Government Corruption)  2018 Dystopia Residual
# 0                            0.315964                2.277027

# %%
# Load/Read happiness_2019
happiness_2019 = "Data sets/Raw Data/Happiness Score/happiness_2019.csv"
k_happiness_2019 = pd.read_csv(happiness_2019)
k_happiness_2019.head(1)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769            1.34           1.587
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
#
#    Perceptions of corruption
# 0                      0.393

# %%
# Swap column indexes - 'Overall Rank' & 'Country or Region'
cols = list(k_happiness_2019.columns)
a, b = cols.index('Country or region'), cols.index('Overall rank')
cols[b], cols[a] = cols[a], cols[b]
k_happiness_2019 = k_happiness_2019[cols]
k_happiness_2019.head(1)
# Out:
#   Country or region  Overall rank  Score  GDP per capita  Social support  \
# 0           Finland             1  7.769            1.34           1.587
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
#
#    Perceptions of corruption
# 0                      0.393

# %%
# Rename Columns with Y2019 Data Identifiers 
happy_2019 = k_happiness_2019.rename(columns={
                                    'Country or region': 'Country', 'Overall rank': '2019 Happiness Rank', 'Score': '2019 Happiness Score',
                                    'GDP per capita': '2019 Economy (GDP per Capita)','Social support': '2019 Family', 
                                    'Healthy life expectancy': '2019 Health (Life Expectancy)', 'Freedom to make life choices': '2019 Freedom', 
                                    'Perceptions of corruption': '2019 Trust (Government Corruption)','Generosity': '2019 Generosity'})
happy_2019.head(1)
# Out:
#    Country  2019 Happiness Rank  2019 Happiness Score  \
# 0  Finland                    1                 7.769
#
#    2019 Economy (GDP per Capita)  2019 Family  2019 Health (Life Expectancy)  \
# 0                           1.34        1.587                          0.986
#
#    2019 Freedom  2019 Generosity  2019 Trust (Government Corruption)
# 0         0.596            0.153                               0.393

# %%
# Double check 'Country or region' if still consistent with just country name as values
cr_list = k_happiness_2019['Country or region'].tolist()
cr_list.sort()
cr_list
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo (Brazzaville)',
#  'Congo (Kinshasa)',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Haiti',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
# ...

# %%
# Load/Read happiness_2020
happiness_2020 = "Data sets/Raw Data/Happiness Score/happiness_2020.csv"
k_happiness_2020 = pd.read_csv(happiness_2020)
k_happiness_2020.head(1)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267         0.95433                71.900825
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.949172   -0.059482                   0.195445
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                  1.972317                           1.28519
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                      1.499526                               0.961271
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                    0.662317                   0.15967
#
# ...

# %%
# Inspect how the Y2020 dataset is differenct compared to prior years
k_happiness_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                153 non-null    object
#  1   Regional indicator                          153 non-null    object
#  2   Ladder score                                153 non-null    float64
#  3   Standard error of ladder score              153 non-null    float64
#  4   upperwhisker                                153 non-null    float64
#  5   lowerwhisker                                153 non-null    float64
#  6   Logged GDP per capita                       153 non-null    float64
#  7   Social support                              153 non-null    float64
#  8   Healthy life expectancy                     153 non-null    float64
# ...

# %%
# Drop Happiness Y2020 variables not found from prior years by column index slicing
slice_happiness2020 = [13, 14, 15, 16, 17, 18, 19]
k_happiness_2020.drop(k_happiness_2020.columns[slice_happiness2020],axis=1, inplace=True)
k_happiness_2020.head(1)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267         0.95433                71.900825
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.949172   -0.059482                   0.195445
#
#    Ladder score in Dystopia
# 0                  1.972317

# %%
# Rename Columns with Y2020 Data Identifiers 
happy_2020 = k_happiness_2020.rename(columns={
                                    'Country name': 'Country', 'Regional indicator': '2020 Region', 'Ladder score': '2020 Ladder score (Happiness Score)', 
                                    'upperwhisker': '2020 upperwhisker', 'lowerwhisker': '2020 lowerwhisker', 'Logged GDP per capita': '2020 Economy (GDP per Capita)', 
                                    'Social support': '2020 Family', 'Healthy life expectancy': '2020 Health (Life Expectancy)', 'Freedom to make life choices': '2020 Freedom', 
                                    'Perceptions of corruption': '2020 Trust (Government Corruption)', 'Generosity': '2020 Generosity', 'Ladder score in Dystopia': '2020 Dystopia Residual',})
happy_2020.head(1)
# Out:
#    Country     2020 Region  2020 Ladder score (Happiness Score)  \
# 0  Finland  Western Europe                               7.8087
#
#    Standard error of ladder score  2020 upperwhisker  2020 lowerwhisker  \
# 0                        0.031156           7.869766           7.747634
#
#    2020 Economy (GDP per Capita)  2020 Family  2020 Health (Life Expectancy)  \
# 0                      10.639267      0.95433                      71.900825
#
#    2020 Freedom  2020 Generosity  2020 Trust (Government Corruption)  \
# 0      0.949172        -0.059482                            0.195445
#
#    2020 Dystopia Residual
# 0                1.972317

# %% [markdown]
# ##### Notes:
#
# - An indicator 'Family' has been changed to 'Social Support' in Y2019.
#
# - No 'Dystopia' (or related) column//values in Y2019.
#
# - Statistics inclusion (Standard Error, Confidence Interval, Whisker.high, low, etc) varies per year.
#
# - Happiness score became 'Ladder score' and the dataset does not include rank, while the other indicators were re-named and new variable terminologies were added in Y2020.

# %% [markdown]
# ### Consolidate the Annual World Happiness Report of 2015-2020

# %%
# Use merge with functools reduce method  in order to integrate all variables per country
from functools import reduce

# Display full column length of the combined dataframe
pd.set_option('display.max_columns', None)

# Merge all World Happiness Report Datasets
happy_dfs = [happy_2015, happy_2016, happy_2017, happy_2018, happy_2019, happy_2020]
all_happiness = reduce(lambda left,right: pd.merge(left,right,on='Country'), happy_dfs)
all_happiness.head()
# Out:
#        Country     2015 Region  2015 Happiness Rank  2015 Happiness Score  \
# 0  Switzerland  Western Europe                    1                 7.587
# 1      Iceland  Western Europe                    2                 7.561
# 2      Denmark  Western Europe                    3                 7.527
# 3       Norway  Western Europe                    4                 7.522
# 4       Canada   North America                    5                 7.427
#
#    2015 Standard Error  2015 Economy (GDP per Capita)  2015 Family  \
# 0              0.03411                        1.39651      1.34951
# 1              0.04884                        1.30232      1.40223
# 2              0.03328                        1.32548      1.36058
# 3              0.03880                        1.45900      1.33095
# 4              0.03553                        1.32629      1.32261
#
#    2015 Health (Life Expectancy)  2015 Freedom  \
# 0                        0.94143       0.66557
# ...

# %%
# Display Consolidated Country List 
country_list = all_happiness['Country'].tolist()
country_list.sort()
country_list
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Benin',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo (Brazzaville)',
#  'Congo (Kinshasa)',
#  'Costa Rica',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'France',
#  'Gabon',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Haiti',
#  'Honduras',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kosovo',
# ...

# %%
# Determine total number of countries in the list. Excluding possible duplicates
happy_countries = len(all_happiness['Country'].unique())
print(f"A total of {happy_countries} countries were included in the The World Happiness Report during 2015-2020")
# Out:
# A total of 138 countries were included in the The World Happiness Report during 2015-2020

# %% [markdown]
# ## Export the Consolidated World Happiness Report (2015-2020)

# %%
# Export consolidated World Happiness Report (2015-2020) to csv & drop index in the process
all_happiness.to_csv('Data sets/Raw Data/Happiness Score/Consolidated_World_Happiness_Report(Detailed)_2015-2020.csv', index=False)

# %% [markdown]
# ## Export only the Happiness Scores per Country for Analysis

# %%
# Display Annual Happiness Scores per Country
happiness_scores = all_happiness[['Country', '2015 Happiness Score', '2016 Happiness Score', '2017 Happiness Score',
                                 '2018 Happiness Score', '2019 Happiness Score', '2020 Ladder score (Happiness Score)']]
# Set Countries as Index
happiness_scores.set_index('Country', inplace=True)
happiness_scores
# Out:
#              2015 Happiness Score  2016 Happiness Score  2017 Happiness Score  \
# Country
# Switzerland                 7.587                 7.509                 7.494
# Iceland                     7.561                 7.501                 7.504
# Denmark                     7.527                 7.526                 7.522
# Norway                      7.522                 7.498                 7.537
# Canada                      7.427                 7.404                 7.316
# ...                           ...                   ...                   ...
# Afghanistan                 3.575                 3.360                 3.794
# Rwanda                      3.465                 3.515                 3.471
# Benin                       3.340                 3.484                 3.657
# Burundi                     2.905                 2.905                 2.905
# Togo                        2.839                 3.303                 3.495
#
# ...

# %%
# Export World Happiness Scores (2015-2020) per Country to csv 
happiness_scores.to_csv('Data sets/Raw Data/Happiness Score/Consolidated_World_Happiness_Report(SCORES)_2015-2020.csv', index=False)
